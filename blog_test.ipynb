# %% [markdown]
# ![AI and Labour Markets](https://images.unsplash.com/photo-1674027444484-cf52149ea050?q=80&w=1932&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D)

# %% [markdown]
# # Does AI Reward High-Skill Work? Evidence from US Labour Markets
#
# AI can write code, summarise documents, draft emails and much more. Many of these tasks are involved in many jobs, so should you be worried — or better paid? This analysis uses data on 670 US occupations to find out whether AI exposure is associated with higher wages, larger employment, and stronger labour demand.
#
# This blog studies the relationship between occupation-level AI exposure, pay, employment, and labour demand in the US. Combining an AI exposure index with labour market data from the Bureau of Labor Statistics and education information from the National Employment Matrix. The analysis is cross sectional and focuses on association rather than causality.
#
# The central finding is that AI exposure is strongly associated with higher wages in raw comparisons, but when you add education level into the regression, the AI wage effect shrinks hugely. In contrast, AI exposure remains positively associated with employment levels, while labour demand shows no robust relationship. Overall, the evidence suggests that AI follows skill it doesn't create it. The wage premium you see is really just a skill premium in disguise, AI hasn't made workers richer, AI just happens to be prominent in high paid jobs.

# %% [markdown]
# ## Research Questions
#
# This blog answers three related questions:
#
# 1. Are occupations with higher AI exposure better paid?
# 2. Are occupations with higher AI exposure larger or smaller in employment?
# 3. Is labour demand stronger in occupations with higher AI exposure?
#
# A further question is whether any observed wage premium remains once occupational skill is taken into account.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import subprocess
subprocess.run(["python", "src/12_figures.py"], check=True, capture_output=True)

sns.set_theme(style="whitegrid", context="talk")
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["axes.spines.top"] = False
plt.rcParams["axes.spines.right"] = False

df = pd.read_csv("data/processed/final_analysis_data.csv")
results = pd.read_csv("output/tables/regression_results.csv")

# %% [markdown]
# ## Data
#
# The analysis is a combination of five occupation level inputs.
#
# First, the AI Occupation Exposure index provides a measure of how exposed occupational tasks are to current AI capabilities. Higher values indicate greater task exposure.
#
# Second, BLS Occupational Employment and Wage Statistics provide employment levels and median annual pay by occupation.
#
# Third, BLS Employment Projections provide average annual occupational openings, which is used as a measure for labour demand.
#
# Fourth, BLS data on entry level education requirements are transformed into an ordinal scale, which serves as a measure of occupational skill.
#
# Finally, SOC occupation codes are used to align occupations across datasets, which ensures a consistent and accurate merge.

# %%
plt.figure()
sns.histplot(df["ai_exposure"], bins=30, kde=True, color="#4A9BAF", edgecolor="white")
plt.title("Distribution of AI Exposure Across Occupations", fontsize=13, fontweight="bold")
plt.xlabel("AI exposure score", fontsize=11)
plt.ylabel("Number of occupations", fontsize=11)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# *Figure 1: Distribution of AI Exposure Across Occupations. Values are standardised  with higher values indicate greater overlap between occupational tasks and current AI capabilities. Source: AI Occupation Exposure Index.*

# %% [markdown]
# Figure 1 shows that AI exposure varies substantially across occupations, with two distinct peaks, suggestingt wo broad clusters of jobs, those with low exposure and those with high exposure. This wide variation means the analysis captures a range of occupations rather than a narrow group of highly technical roles.

# %%
plt.figure()
sns.regplot(
    x="ai_exposure",
    y="log_pay",
    data=df,
    scatter_kws={"alpha": 0.6, "s": 40, "color": "#4A9BAF"},
    line_kws={"linewidth": 2, "color": "#D4957A"}
)
plt.title("AI Exposure and Occupational Pay", fontsize=13, fontweight="bold")
plt.xlabel("AI exposure score", fontsize=11)
plt.ylabel("Log weekly pay", fontsize=11)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# *Figure 2: AI Exposure and Log Weekly Pay by Occupation. Each point represents one occupation. The x-axis shows standardised AI exposure (higher values indicate greater exposure)  and the y-axis shows log weekly pay in USD. Source: AI Occupation Exposure Index and BLS Occupational Employment and Wage Statistics.*

# %% [markdown]
# Figure 2 shows, occupations with higher AI exposure are generally better paid. However this should not be interpreted as direct evidence that AI benefits workers. Jobs with a high AI exposure score are typically more skilled, menaing the pay premium may reflect skill rather than AI exposure itself.

# %%
plt.figure()
sns.regplot(
    x="ai_exposure",
    y="log_employment",
    data=df,
    scatter_kws={"alpha": 0.6, "s": 40, "color": "#7BB5A0"},
    line_kws={"linewidth": 2, "color": "#D4957A"}
)
plt.title("AI Exposure and Employment Levels", fontsize=13, fontweight="bold")
plt.xlabel("AI exposure score", fontsize=11)
plt.ylabel("Log employment", fontsize=11)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# *Figure 3: AI Exposure and Employment Levels by Occupation. Each point represents one occupation. The x-axis shows standardised AI exposure and the y-axis shows log employment. Source: AI Occupation Exposure Index and BLS OEWS.*

# %% [markdown]
# Figure 3 shows a weak positive relationship between AI exposure and employment levels, with considerable variation across occupations. While uncertain, this suggests that highly exposed occupations are not systematically smaller in the labour market. AI exposure doesn't appear to be concentrated in disappearing roles.

# %%
quartile_summary = (
    df.groupby("exposure_quantile", observed=False)["weekly_pay"]
    .mean()
    .reset_index()
)

order = ["Low", "Lower-middle", "Upper-middle", "High"]

plt.figure()
sns.barplot(data=quartile_summary, x="exposure_quantile", y="weekly_pay", 
            color="#7BB5A0", order=order)
plt.title("Average Weekly Pay by AI Exposure Group", fontsize=13, fontweight="bold")
plt.xlabel("AI exposure quartile", fontsize=11)
plt.ylabel("Average weekly pay (USD)", fontsize=11)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# *Figure 4: Average Weekly Pay Across AI Exposure Groups. Occupations are divided into quartiles based on their AI exposure level. Source: AI Occupation Exposure Index and BLS OEWS.*

# %% [markdown]
# Figure 4 shows a clear stepwise incerease in average pay rises across AI exposure groups, with high exposure occupations earning nearly double that of low exposure ones. This reinforces the raw positive association between AI exposure and wages. Still, this figure does not tell us whether AI exposure itself matters once skill is taken into account.

# %%
skill_summary = (
    df.groupby("skill")["weekly_pay"]
    .mean()
    .reset_index()
)

plt.figure()
sns.barplot(data=skill_summary, x="skill", y="weekly_pay", color="#4A9BAF")
plt.title("Higher-Skill Occupations Have Higher Pay", fontsize=13, fontweight="bold")
plt.xlabel("Skill level", fontsize=11)
plt.xticks(ticks=range(7), labels=range(7))
plt.ylabel("Average weekly pay (USD)", fontsize=11)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# *Figure 5: Average weekly pay by occupational skill groups. Skill is measured using BLS typical entry level education requirements converted to an ordinal scale from 0( no formal education) to 6 (doctoral degree). Source: BLS OEWS and BLS Education data.*

# %% [markdown]
# Pay increases strongly with occupational skill. Shown in the graph as average weekly pay more than doubles from around $41,000 at skill level 0 to over $100,000 at skill level 6. This is important because if AI exposure is concentrated in occupations with high education requirements, then the apparent AI wage premium may really be a skill premium.

# %%
import pandas as pd
df = pd.read_csv('data/processed/final_analysis_data.csv')

summary = df[['ai_exposure', 'weekly_pay', 'employment_2023_x', 'skill']].describe()
summary.index = ['Count', 'Mean', 'Std Dev', 'Min', '25th %ile', 'Median', '75th %ile', 'Max']
summary.columns = ['AI Exposure', 'Weekly Pay (USD)', 'Employment', 'Skill Level']

summary['AI Exposure'] = summary['AI Exposure'].round(3)
summary['Weekly Pay (USD)'] = summary['Weekly Pay (USD)'].round(0).astype(int)
summary['Employment'] = summary['Employment'].round(0).astype(int)
summary['Skill Level'] = summary['Skill Level'].round(2)

summary.style.set_caption("Table 1: Summary Statistics").format({
    'AI Exposure': '{:.3f}',
    'Weekly Pay (USD)': '{:,.0f}',
    'Employment': '{:,.0f}',
    'Skill Level': '{:.2f}'
}).format(subset=pd.IndexSlice['Count', :], formatter='{:.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_57f06">
#   <caption>Table 1: Summary Statistics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57f06_level0_col0" class="col_heading level0 col0" >AI Exposure</th>
#       <th id="T_57f06_level0_col1" class="col_heading level0 col1" >Weekly Pay (USD)</th>
#       <th id="T_57f06_level0_col2" class="col_heading level0 col2" >Employment</th>
#       <th id="T_57f06_level0_col3" class="col_heading level0 col3" >Skill Level</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57f06_level0_row0" class="row_heading level0 row0" >Count</th>
#       <td id="T_57f06_row0_col0" class="data row0 col0" >670</td>
#       <td id="T_57f06_row0_col1" class="data row0 col1" >670</td>
#       <td id="T_57f06_row0_col2" class="data row0 col2" >670</td>
#       <td id="T_57f06_row0_col3" class="data row0 col3" >670</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# The dataset contains 670 occupations. AI exposure is standardised with a mean near zero (negative values indicate a below average exposure and positive values indicate an above average exposure). Weekly pay and employment are highly skewed, which motivates the use of log transformations in the regression analysis. Skill level is measured on an ordinal scale from 0( no formal education required) to 6( doctoral degree required).

# %% [markdown]
# ## Regression Results
#
# To test this more formally, I estimate occupation-level regressions for wages, employment, and labour demand. The baseline specification includes AI exposure only. I then add the skill measure, and finally an interaction between AI exposure and skill.
#
# The wage results are the most revealing. In the baseline model, AI exposure is positively associated with pay. However, once skill is included, the AI coefficient falls sharply. This indicates that much of the baseline wage relationship reflects the fact that high-AI occupations are also high-skill occupations.
#
# Employment results tell a different story. While the raw scatter plot suggests only a slight positive relationship, AI exposure remains positively associated with employment levels even after controlling for skill, suggesting the relationship is not simply driven by differences in occupational skill levels.
#
# For labour demand, measured using average annual occupational openings, there is no strong relationship with AI exposure once controls are included. This is an intersting find, as while AI exposed occupations tend to pay more, they are not necessarily growing faster than less exposed roles

# %%
wage_results = results[results["outcome"] == "log_pay"].copy()
employment_results = results[results["outcome"] == "log_employment"].copy()
demand_results = results[results["outcome"] == "advert_intensity"].copy()

# Show only baseline and with_skill specs, full sample only
key_models = ["baseline_full", "with_skill_full"]

wage_summary = wage_results[
    (wage_results["model"].isin(key_models)) &
    (wage_results["term"].isin(["ai_exposure", "skill"]))
][["model", "term", "coef", "p_value"]].copy()

wage_summary["model"] = wage_summary["model"].replace({
    "baseline_full": "Baseline",
    "with_skill_full": "With Skill Controls"
})

wage_summary["coef"] = wage_summary["coef"].round(4)
wage_summary["p_value"] = wage_summary["p_value"].round(3)
wage_summary.columns = ["Model", "Term", "Coefficient", "P-Value"]

styled = wage_summary.style.format({"Coefficient": "{:.4f}", "P-Value": "{:.3f}"})
styled = styled.set_caption("Table 2: Wage Regression Results (Full Sample)")
styled = styled.hide(axis="index")
styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_061d5">
#   <caption>Table 2: Wage Regression Results (Full Sample)</caption>
#   <thead>
#     <tr>
#       <th id="T_061d5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_061d5_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_061d5_level0_col2" class="col_heading level0 col2" >Coefficient</th>
#       <th id="T_061d5_level0_col3" class="col_heading level0 col3" >P-Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_061d5_row0_col0" class="data row0 col0" >Baseline</td>
#       <td id="T_061d5_row0_col1" class="data row0 col1" >ai_exposure</td>
#       <td id="T_061d5_row0_col2" class="data row0 col2" >0.2174</td>
#       <td id="T_061d5_row0_col3" class="data row0 col3" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_061d5_row1_col0" class="data row1 col0" >With Skill Controls</td>
# ...

# %% [markdown]
# The wage results are the most revealing. In the baseline model, a one unit increase in AI exposure is associated with around 22% higher weekly pay, which is a substantial difference. However once skill is added to the model, this relationship shrinks dramatically. The AI exposure coefficient falls from 0.217 to 0.029. This makes it no longer statistically significant, meaning we can't confidently say AI exposure itself is driving higher wages. Skill on the other hand, remains strongly significant with a coefficient of 0.146. This tells us that the pay premium that appears to come with AI exposure is largely explained by the fact that AI exposed occupations tend to require higher levels of education and skill. In other words, it is not AI exposure which makes a job well paid, it is the skill that is required to do it.

# %%
employment_summary = employment_results[
    (employment_results["model"].isin(key_models)) &
    (employment_results["term"].isin(["ai_exposure", "skill"]))
][["model", "term", "coef", "p_value"]].copy()

employment_summary["model"] = employment_summary["model"].replace({
    "baseline_full": "Baseline",
    "with_skill_full": "With Skill Controls"
})

employment_summary["coef"] = employment_summary["coef"].round(4)
employment_summary["p_value"] = employment_summary["p_value"].round(3)
employment_summary.columns = ["Model", "Term", "Coefficient", "P-Value"]

styled = employment_summary.style.format({"Coefficient": "{:.4f}", "P-Value": "{:.3f}"})
styled = styled.set_caption("Table 3: Employment Regression Results (Full Sample)")
styled = styled.hide(axis="index")
styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_9642d">
#   <caption>Table 3: Employment Regression Results (Full Sample)</caption>
#   <thead>
#     <tr>
#       <th id="T_9642d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9642d_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_9642d_level0_col2" class="col_heading level0 col2" >Coefficient</th>
#       <th id="T_9642d_level0_col3" class="col_heading level0 col3" >P-Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9642d_row0_col0" class="data row0 col0" >Baseline</td>
#       <td id="T_9642d_row0_col1" class="data row0 col1" >ai_exposure</td>
#       <td id="T_9642d_row0_col2" class="data row0 col2" >0.1337</td>
#       <td id="T_9642d_row0_col3" class="data row0 col3" >0.041</td>
#     </tr>
#     <tr>
#       <td id="T_9642d_row1_col0" class="data row1 col0" >With Skill Controls</td>
# ...

# %% [markdown]
# The employment results are interesting. In the baseline model, AI exposure is positively associated with employment levels. Interestingly, once skill is controlled for, this relationship becomes even stronger, the coefficient rises from 0.134 to 0.473, which suggests that skill was masking the true relationship. Skill itself is negatively associated with employment, which makes intuitive sense since highly skilled occupations tend to be smaller in number. This suggests therefore that highly AI exposed occupations tend to have more workers employed in them, even after accounting for skill levels.

# %%
demand_summary = demand_results[
    demand_results["model"].isin(["baseline_full", "with_skill_full"]) &
    demand_results["term"].isin(["ai_exposure", "skill"])
][["model", "term", "coef", "p_value"]].copy()

demand_summary["model"] = demand_summary["model"].replace({
    "baseline_full": "Baseline",
    "with_skill_full": "With Skill Controls"
})

demand_summary["coef"] = demand_summary["coef"].round(6)
demand_summary["p_value"] = demand_summary["p_value"].round(3)
demand_summary.columns = ["Model", "Term", "Coefficient", "P-Value"]

styled = demand_summary.style.set_caption("Table 4: Labour Demand Regression Results")
styled = styled.hide(axis="index")
styled = styled.format({"Coefficient": "{:.6f}", "P-Value": "{:.3f}"})
styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5d40">
#   <caption>Table 4: Labour Demand Regression Results</caption>
#   <thead>
#     <tr>
#       <th id="T_c5d40_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c5d40_level0_col1" class="col_heading level0 col1" >Term</th>
#       <th id="T_c5d40_level0_col2" class="col_heading level0 col2" >Coefficient</th>
#       <th id="T_c5d40_level0_col3" class="col_heading level0 col3" >P-Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c5d40_row0_col0" class="data row0 col0" >Baseline</td>
#       <td id="T_c5d40_row0_col1" class="data row0 col1" >ai_exposure</td>
#       <td id="T_c5d40_row0_col2" class="data row0 col2" >-0.000022</td>
#       <td id="T_c5d40_row0_col3" class="data row0 col3" >0.012</td>
#     </tr>
#     <tr>
#       <td id="T_c5d40_row1_col0" class="data row1 col0" >With Skill Controls</td>
# ...

# %% [markdown]
# The labour demand regression results tell us something different. While AI exposure appears negatively associated with job openings in the baseline model, this relationship disppears entirely once skill is controlled for, the p value rises to 0.947, meaning there is essentially no relationship at all. Neither AI exposure nor skill significantly predicts labour demand. This suggets that AI exposed occupations are not seeing systematically more or fewer job openings than less exposed ones.

# %% [markdown]
# ## Robustness Checks
#
# I use two robustness checks for the wage results.
#
# First, I trim the top 5% of occupations by weekly pay, removing outliers such as surgeons and CEOs, to test whether the main findings are driven by a small number of extremely highly paid occupations.
#
# Second, I estimate median regressions. These are less sensitive to skewness in the wage distribution and therefore provide a useful check on whether the baseline results are driven by the upper tail.
#
# Both checks confirm the main findings. The AI exposure coefficient remains small and statistically insignificant once skill is controlled for regardless or whether outliers are excluded or median regression is used.

# %%
robust_compare = results[
    (results["outcome"] == "log_pay") &
    (results["term"] == "ai_exposure") &
    (results["model"].isin([
        "baseline_full", "with_skill_full",
        "baseline_trimmed", "with_skill_trimmed",
        "baseline_median", "with_skill_median"
    ]))
][["model", "coef", "p_value"]].copy()

robust_compare["model"] = robust_compare["model"].replace({
    "baseline_full": "Baseline",
    "with_skill_full": "With Skill Controls",
    "baseline_trimmed": "Baseline (Trimmed)",
    "with_skill_trimmed": "With Skill Controls (Trimmed)",
    "baseline_median": "Baseline (Median)",
    "with_skill_median": "With Skill Controls (Median)"
})

robust_compare["coef"] = robust_compare["coef"].round(4)
robust_compare["p_value"] = robust_compare["p_value"].round(3)
robust_compare.columns = ["Specification", "AI Exposure Coefficient", "P-Value"]
robust_compare.style.format({"AI Exposure Coefficient": "{:.4f}", "P-Value": "{:.3f}"}) \
    .set_caption("Table 5: Robustness Checks — AI Exposure Coefficient on Log Wages") \
    .hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9c1da">
#   <caption>Table 5: Robustness Checks — AI Exposure Coefficient on Log Wages</caption>
#   <thead>
#     <tr>
#       <th id="T_9c1da_level0_col0" class="col_heading level0 col0" >Specification</th>
#       <th id="T_9c1da_level0_col1" class="col_heading level0 col1" >AI Exposure Coefficient</th>
#       <th id="T_9c1da_level0_col2" class="col_heading level0 col2" >P-Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9c1da_row0_col0" class="data row0 col0" >Baseline</td>
#       <td id="T_9c1da_row0_col1" class="data row0 col1" >0.2174</td>
#       <td id="T_9c1da_row0_col2" class="data row0 col2" >0.000</td>
#     </tr>
#     <tr>
#       <td id="T_9c1da_row1_col0" class="data row1 col0" >With Skill Controls</td>
#       <td id="T_9c1da_row1_col1" class="data row1 col1" >0.0287</td>
#       <td id="T_9c1da_row1_col2" class="data row1 col2" >0.056</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# The robustness checks broadly support the main findings. Trimming the top 5% of wages leaves the overall pattern intact, although the controlled AI coefficient remains marginally significant (p=0.021), which suggests a small association with pay. The median regression is more conclusive, once skill is controlled for the AI coefficient falls to just 0.007 and becomes statistically insignificant (p=0.718). Overall, the evidence consistently points to skill rather than AI exposure as the main driver of occupational pay.

# %% [markdown]
# ## Interpretation
#
# Taken together, the findings suggest that AI is concentrated in occupations that are already advantaged. These occupations tend to require more education, pay more, and in many cases employ large numbers of workers. However, the wage premium associated with AI exposure is mostly explained by skill rather than by AI exposure itself.
#
# This matters for the economic interpretation. The results support a skill-biased allocation story more than a pure complementarity story. AI appears to be associated with high-skill work, but the evidence does not show that AI independently increases wage returns once occupational skill is taken into account.

# %% [markdown]
# ## Limitations
#
# This project has several limitations.
#
# First, the analysis is cross-sectional, meaning it captures a single snapshot in time rather than tracking changes over time and does not identify causal effects. The results should therefore be interpreted as associations.
#
# Second, occupation-level averages hide substantial variation within occupations. Two workers in the same occupation may use AI very differently.
#
# Third, the AI exposure measure captures task exposure rather than realised AI adoption. Exposure does not necessarily imply that employers have already adopted these tools at scale.
#
# Fourth, labour demand is measured using projected occupational openings rather than real-time job postings. This is a reasonable measure, but it captures medium-run demand rather than short-run hiring dynamics.
#
# These findings should be interpreted with caution. The data reflects occupational conditions in 2023, a period when AI adoption was still in its early stages. It is possible that the labour market effects of AI exposure will become more pronounced over time as adoption accelerates. The AI exposure scores themselves are also based on 2023 AI capabilities, which have since advanced considerably.

# %% [markdown]
# ## Machine Learning Evidence
#
# To complement the regression analysis, I train a Random Forest model to predict log wages from occupation characteristics. Unlike standard regression, Random Forests can capture nonlinear relationships and interactions between features without requiring them to be specified in advance.
#
# The cross-validated R² ( a measure of how well the model predicts wages on unseen data) is close to zero, reflecting the small sample size. However, predictive accuracy is not the main concern here. The real value of this approach is in identifying which factors play the biggest role in determinig occupational pay without relying on assumptions of standard regression.

# %%
fi = pd.read_csv("output/tables/ml_feature_importance.csv")
fi = fi.sort_values("importance", ascending=True)

colors = ["#D4957A", "#6B9E8F", "#C4825A", "#7BB5A0", "#4A9BAF"]

fig, ax = plt.subplots(figsize=(9, 5))
bars = ax.barh(fi["feature_label"], fi["importance"], color=colors[:len(fi)], edgecolor="white")
ax.bar_label(bars, fmt="%.3f", padding=3, fontsize=9)
ax.spines[["top", "right"]].set_visible(False)
ax.set_title("What Predicts Wages? Random Forest Feature Importance",
             fontsize=13, fontweight="bold")
ax.set_xlabel("Feature Importance (Mean Decrease in Impurity)", fontsize=11)
ax.set_xlim(0, fi["importance"].max() * 1.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Figure 6: Random Forest Feature Importance for Predicting Log Wages.
# Importance scores reflect the average reduction in impurity across all
# trees. Higher values indicate greater predictive contribution.
# Source: Author's calculations.*

# %% [markdown]
# Figure 6 reinforces the regression findings. Education level dominates with an importance score of 0.722, followed by job advert intensity at 0.192. AI exposure ranks third at 0.048, which confirms that skill is the main driver of occupational pay. The low importance of the AI skill interaction term also suggests that the effect of AI exposure doesn't vary significantly across skill groups.

# %% [markdown]
# ## Conclusion
#
# This project examined whether occupation-level AI exposure is associated with wages, employment, and labour demand in the United States.
#
# The raw data shows a clear positive relationship between AI exposure and wages. But once occupational skill is controlled for, this wage effect disappears depending on specification. This indicates that the apparent AI wage premium largely reflects the fact that AI is concentrated in high-skill occupations.
#
# By contrast, AI exposure remains positively associated with employment levels, suggesting that highly exposed occupations are not marginal or shrinking parts of the labour market. Labour demand, measured through projected occupational openings, shows no robust relationship with AI exposure.
#
# From a policy perspective, these findings suggest that interventions aimed at improving wages in AI-exposed occupations may be more effective if targeted at expanding access to education and skill development rather than AI adoption alone. If the wage premium associated with AI is primarily a skill premium, then policies focusing on upskilling workers may do more to reduce occupational inequality than those focused on AI diffusion specifically.
#
# This conclusion is also supported by the Random Forest analysis which identifies education level as the strongest predictor of occupational pay.
#
# Overall, the results suggest that AI is concentrated in high-skill, high-paying occupations, but does not independently raise wage returns once skill is taken into account. The main implication is that AI may reinforce existing occupational inequalities not because it directly rewards exposure, but because it is most prevalent in occupations that are already skill intensive.

# %% [markdown]
# ## Replication Note
#
# All data cleaning, merging, feature construction, regression analysis, and robustness checks are scripted in the `src/` folder of the GitHub repository. The notebook uses the final processed dataset and saved regression outputs generated by that pipeline.
